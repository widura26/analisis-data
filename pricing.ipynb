# %%
import pandas as pd

# %%
data = pd.read_csv('./estimate.csv')
exchange_rate = 14000

data['total_price, IDR'] = data['total_price, USD'] * exchange_rate
data
# Out:
#                                                 name   quantity  \
# 0                E2 Instance Core running in Jakarta     1458.0
# 1                 E2 Instance Ram running in Jakarta     1458.0
# 2                    Balanced PD Capacity in Jakarta       10.0
# 3       Cloud SQL for MySQL: Zonal - vCPU in Jakarta      730.0
# 4        Cloud SQL for MySQL: Zonal - RAM in Jakarta     2737.5
# 5  Cloud SQL for MySQL: Zonal - Standard storage ...     7300.0
# 6                      Cloud SQL: Backups in Jakarta    73000.0
# 7               Regional Standard Class A Operations  1000000.0
# 8                           Standard Storage Jakarta       10.0
#
#             region      service_id             sku  total_price, USD  notes  \
# 0  asia-southeast2  6F81-5844-456A  621C-41D1-4D05          42.76481    NaN
# 1  asia-southeast2  6F81-5844-456A  2526-CC04-D642           5.73063    NaN
# 2  asia-southeast2  6F81-5844-456A  7CD6-D519-82F7           1.30000    NaN
# ...

# %%
total_price = data['total_price, IDR'].sum()
print(total_price)
# Out:
# 1831772.04
